# %% [markdown]
# <a href="https://colab.research.google.com/github/kunalssharma125-pixe/machinelearning1/blob/main/LAB_02_%2B_HEATMAP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
x = np.array([1,3,5,7,8,9,10,15])
y = np.array([10,20,30,40,50,60,70,80])

# %%
def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_xy = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x_squared = sum((X-X.mean())**2)
        Sum_y_squared = sum((Y-Y.mean())**2)
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr

print(Pearson_correlation(x,y))
print(Pearson_correlation(x,x))
# Out:
# 0.974894414261588
# 1.0

# %%
import numpy as np

x1 = np.array([1,3,5,7,8,9, 10, 15])
y1 = np.array([80, 70, 60, 50, 40, 30, 20, 10])

# %%
def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_xy = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x_squared = sum((X-X.mean())**2)
        Sum_y_squared = sum((Y-Y.mean())**2)
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr

print(Pearson_correlation(x1,y1))
print(Pearson_correlation(x1,x1))
# Out:
# -0.974894414261588
# 1.0

# %%
import numpy as np

x1 = np.array([1,3,5,7,8,9, 10, 15])
y1 = np.array([88, 777, 66, 555, 44, 333, 22, 11])

# %%
def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_xy = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x_squared = sum((X-X.mean())**2)
        Sum_y_squared = sum((Y-Y.mean())**2)
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr

print(Pearson_correlation(x1,y1))
print(Pearson_correlation(x1,x1))
# Out:
# -0.3812900419462779
# 1.0

# %%
import pandas as pd
df = pd.read_csv('insurance.csv')

# %%
corr = df.corr(method = 'pearson')
corr
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("insurance.csv")

# %%
data_numeric = data.copy()

# %%
for col in data_numeric.select_dtypes(include=['object']).columns:
    data_numeric[col] = data_numeric[col].astype('category').cat.codes

# %%
corr = data_numeric.corr()

# %%
plt.figure(figsize=(8,6))
im = plt.imshow(corr)
plt.colorbar()

# %%
for i in range(len(corr)):
    for j in range(len(corr.columns)):
        plt.text(j, i, f"{corr.iloc[i, j]:.2f}",
                 ha='center', va='center',
                 color='black', fontsize=8)

# %%
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title("Correlation Heatmap with Values")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("insurance.csv")

# %%
co_mtx = data.corr(numeric_only=True)

# %%
print(co_mtx)
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(co_mtx, cmap="YlGnBu", annot=True, fmt=".2f")
# Out:
# <Axes: >

# %%
plt.title("Correlation Heatmap of Insurance Dataset")
plt.show()
